# %% [markdown]
# #*Instalación librerías*

# %%
! pip install BeautifulSoup4
! pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.9.24)

# %% [markdown]
# #*Carga de Librerías*

# %%
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime

# %% [markdown]
# #*Scraping*

# %% [markdown]
# ***Extracción de texto***

# %%
# indicar la ruta
url_page = 'http://www.bolsamadrid.es/esp/aspx/Indices/Resumen.aspx'
# tarda 480 milisegundos
page = requests.get(url_page).text 
soup = BeautifulSoup(page, "lxml")
# Obtenemos la tabla por un ID específico
tabla = soup.find('table', attrs={'id': 'ctl00_Contenido_tblÍndices'})

# %% [markdown]
# ***Ejemplos***

# %%
# Obtenemos la tabla por un ID específico
tabla = soup.find('table', attrs={'id': 'ctl00_Contenido_tblÍndices'})

# %%
url_page = 'https://www.lifeder.com/cientificos-famosos/'
page = requests.get(url_page).text 
soup = BeautifulSoup(page, "lxml")
contenido = soup.find('div', attrs={'class': 'td-post-content'})
items = contenido.find_all('a')
for item in items:
    print(item['href'])
# Out:
# https://www.lifeder.com/personajes-historicos/
# https://www.lifeder.com/sol/
# https://www.lifeder.com/pasos-metodo-cientifico/
# https://www.lifeder.com/plantas/
# https://www.lifeder.com/sistema-nervioso/
# https://www.lifeder.com/adn/
# https://www.lifeder.com/efecto-invernadero/
# https://www.lifeder.com/caracteristicas-literatura/
# https://www.lifeder.com/condicionamiento-clasico/
# https://www.lifeder.com/cientificos-famosos/
# #

# %% [markdown]
# ***Limpieza de Links***

# %%
l = []
for i in items:
     l.extend([str(i).split('href="')[1].split('/"')[0] ])   
l
# Out:
# ['https://www.lifeder.com/personajes-historicos',
#  'https://www.lifeder.com/sol',
#  'https://www.lifeder.com/pasos-metodo-cientifico',
#  'https://www.lifeder.com/plantas',
#  'https://www.lifeder.com/sistema-nervioso',
#  'https://www.lifeder.com/adn',
#  'https://www.lifeder.com/efecto-invernadero',
#  'https://www.lifeder.com/caracteristicas-literatura',
#  'https://www.lifeder.com/condicionamiento-clasico',
#  'https://www.lifeder.com/cientificos-famosos',
#  '#">Copiar cita</a>']

# %% [markdown]
# ***Extracción de los elementos que son links***

# %%
ln = []
for i in l:
   ln.extend([i if 'https:' in i else ''])
ln
while '' in ln:
    ln.remove('')
ln
# Out:
# ['https://www.lifeder.com/personajes-historicos',
#  'https://www.lifeder.com/sol',
#  'https://www.lifeder.com/pasos-metodo-cientifico',
#  'https://www.lifeder.com/plantas',
#  'https://www.lifeder.com/sistema-nervioso',
#  'https://www.lifeder.com/adn',
#  'https://www.lifeder.com/efecto-invernadero',
#  'https://www.lifeder.com/caracteristicas-literatura',
#  'https://www.lifeder.com/condicionamiento-clasico',
#  'https://www.lifeder.com/cientificos-famosos']

# %% [markdown]
# ***Extraemos el texto del primer link***

# %%
requests.get(ln[0]).text
# Out:
# '<!doctype html >\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="es"> <!--<![endif]-->\n<head>\n<title>Los 55 personajes históricos más importantes</title>\n<script async src="https://cse.google.com/cse.js?cx=aa1e671c84d089ed7"></script>\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="pingback" href="https://www.lifeder.com/xmlrpc.php" />\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel="icon" type="image/png" href="/wp-content/uploads/2015/05/favicon.ico">\n\n<meta name="description" content="Hay cientos de\xa0personajes históricos\xa0ilustres y\xa0famosos que han influido de manera importante en el mundo, ya sea con sus ideas, acciones, inventos o descubrimientos. Lamentablemente, otros influyeron para el mal de la humanidad." />\n<link rel="canonical" href="https://www.lifeder.com/personajes-historicos/" />\n<meta property="og:locale" content="es_ES" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Los 55 personajes históricos más importantes" />\n<meta property="og:description" content="Hay cientos de\xa0personajes históricos\xa0ilustres y\xa0famosos que han influido de manera importante en el mundo, ya sea con sus ideas, acciones, inventos o descubrimientos. Lamentablemente, otros influyeron para el mal de la humanidad." />\n<meta property="og:url" content="https://www.lifeder.com/personajes-historicos/" />\n<meta property="og:site_name" content="Lifeder" />\n<meta property="article:publisher" content="https://www.facebook.com/lifeders/" />\n<meta property="article:section" content="Curiosidades" />\n<meta property="article:published_time" content="2022-02-11T00:59:13+01:00" />\n<meta property="article:modified_time" content="2022-03-08T01:24:32+01:00" />\n<meta property="og:updated_time" content="2022-03-08T01:24:32+01:00" />\n<meta property="og:image" content="https://www.lifeder.com/wp-content/uploads/2016/02/Cleopatra-lifeder.jpg" />\n<meta property="og:image:secure_url" content="https://www.lifeder.com/wp-content/uploads/2016/02/Cleopatra-lifeder.jpg" />\n<meta property="og:image:width" content="397" />\n<meta property="og:image:height" content="480" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:description" content="Hay cientos de\xa0personajes históricos\xa0ilustres y\xa0famosos que han influido de manera importante en el mundo, ya sea con sus ideas, acciones, inventos o descubrimientos. Lamentablemente, otros influyeron para el mal de la humanidad." />\n<meta name="twitter:title" content="Los 55 personajes históricos más importantes" />\n<meta name="twitter:site" content="@lifeder" />\n<meta name="twitter:image" content="https://www.lifeder.com/wp-content/uploads/2016/02/Cleopatra-lifeder.jpg" />\n<meta name="twitter:creator" content="@lifeder" />\n<script type=\'application/ld+json\' class=\'yoast-schema-graph yoast-schema-graph--main\'>{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.lifeder.com/#organization","name":"lifeder","url":"https://www.lifeder.com/","sameAs":["https://www.facebook.com/lifeders/","https://www.youtube.com/channel/UCiP5vmNYR-LuUA3LARZBAoQ","https://twitter.com/lifeder"],"logo":{"@type":"ImageObject","@id":"https://www.lifeder.com/#logo","url":false,"caption":"lifeder"},"image":{"@id":"https://www.lifeder.com/#logo"}},{"@type":"WebSite","@id":"https://www.lifeder.com/#website","url":"https://www.lifeder.com/","name":"Lifeder","publisher":{"@id":"https://www.lifeder.com/#organization"},"potentialAction":{"@type":"SearchAction","target":"https://www.lifeder.com/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"https://www.lifeder.com/personajes-historicos/#primaryimage","url":"https://www.lifeder.com/wp-content/uploads/2016/02/Cleopa ...
